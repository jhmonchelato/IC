# %%
import pandas as pd
import numpy as np
import re

# %%
def read_swc(arquivo):
    
    df = pd.read_csv(arquivo, header=None)
    display(df)
    colunas = ['knot','tipo','x', 'y','z', 'raio','pai']
    remove = []
    for i, row in df.iterrows():
        linha = row[0].strip()
        if linha[0] == '#':
            remove.append(i)
        if linha[0] == '1':
            break
    
    df = pd.read_csv(arquivo, skiprows=remove, header=None, sep=' ')
    df.drop([0],axis=1, inplace=True) #Tira a primera coluna quando tem um espaco
    df.columns = colunas
    df.loc[0, 'pai'] = 1
    
    return df

df = read_swc(arquivo='neuron-1.swc')
display(df)
# Out:
#                                                       0
# 0     # SWC to SWC conversion from L-Measure. Sridev...
# 1     # Original fileName:C:\Users\Carolina\Desktop\...
# 2                                                     #
# 3     # SWC to SWC conversion from L-Measure. Sridev...
# 4     # Original fileName:C:\NMO_dev\data_proc\Adke_...
# ...                                                 ...
# 1749              1721 3 16.19 -199.54 -27.36 0.43 1720
# 1750             1722 3 16.19 -200.24 -27.33 0.405 1721
# 1751             1723 3 16.26 -201.04 -27.68 0.345 1722
# 1752             1724 3 15.96 -201.74 -27.72 0.325 1723
# 1753              1725 3 15.59 -202.34 -27.7 0.315 1724
#
# [1754 rows x 1 columns]
#       knot  tipo      x       y      z   raio   pai
# 0        1     1   0.00    0.00   0.00  8.054     1
# 1        2     1   3.14    6.24   3.98  8.054     1
# 2        3     1  -3.14   -6.23  -3.97  8.054     1
# 3        4     3   6.59    4.59  -2.46  1.220     1
# ...

# %%
head = df_mouse.iloc[[0]]
np.array(head)
head
# Out:
#       0          1            2        3       4             5        6   \
# 0  title  neuron_id  Neuron_name  Surface  Volume  Soma_Surface  N_stems
#
#        7         8      9   ...            14            15           16  \
# 0  N_bifs  N_branch  Width  ...  PathDistance  Branch_Order  Contraction
#
#               17                   18          19              20  \
# 0  Fragmentation  Partition_asymmetry  Pk_classic  Bif_ampl_local
#
#             21               22      23
# 0  Fractal_Dim  Bif_ampl_remote  Length
#
# [1 rows x 24 columns]

# %%
df_mouse = pd.read_csv('../dados/csv/humano.csv')

df_mouse2 = df_mouse.T

display(df_mouse, df_mouse2)
df_mouse = df_mouse[['N_stems','N_bifs', 'N_branch', 'Length']]
df_mouse = df_mouse.astype({"N_stems": float, "N_bifs": float, "N_branch": float})
means = df_mouse.mean()
print(f'Media das medidas: \n{means}\n')

# Pega a menor diferenca entre respectivo atributo e a media geral do atributo

distancias = []
for index, linha in df_mouse.iterrows():
    
    dist = np.sqrt((means['N_stems'] - linha['N_stems'])**2 + (means['N_branch'] - linha['N_branch'])**2 + 
                   (means['N_bifs'] - linha['N_bifs'])**2 + (means['Length'] - linha['Length'])**2)
    
    distancias.append(dist)

    
neuron = distancias.index(min(distancias))
indices = np.argsort(distancias)
df_mouse.iloc[indices[25]]
# Out:
#                   title                  139       185      184      145  \
# 0             neuron_id                 1065      3513     3524     4894
# 1           Neuron_name  07a_pyramidal13aACC     1-2-2    1-5-3  132-3-9
# 2               Surface              8269.57   15009.3  13567.1  8010.94
# 3                Volume              3220.44   4668.45  4462.72  2452.73
# 4          Soma_Surface              940.757   1223.91  843.552  1164.54
# 5               N_stems                    6         8        7        7
# 6                N_bifs                  172        36       30       28
# 7              N_branch                  350        80       67       63
# 8                 Width              161.732   273.451   345.09   328.67
# 9                Height              325.729    471.83   318.53   311.23
# 10                Depth               136.87    129.18    92.75    116.8
# 11             Diameter              1.36764  0.721144     0.91     0.56
# ...

# %%
df_mouse = pd.read_csv('conjunto-1-mouse-DSA.csv')
display(df_mouse.loc[2633])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11444/155197958.py in <module>
# ----> 1 df_mouse = pd.read_csv('conjunto-1-mouse-DSA.csv')
#       2 display(df_mouse.loc[2633])
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
df_mouse = pd.read_csv('conjunto-1-mouse-FULL.csv')
N = df_mouse['N_bifs']
media = np.mean(N)
print(media)
# Out:
# 52.425634328924794
# C:\Users\jh-mo\AppData\Local\Programs\Python\Python310\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_human = pd.read_csv('conjunto-1-human-DSA.csv')
N = df_human['N_bifs']
media = np.mean(N)
print(media)
# Out:
# 55.86080947680158

# %%
df_human = pd.read_csv('conjunto-1-human-FULL.csv')
N = df_human['N_bifs']
media = np.mean(N)
print(media)
# Out:
# 30.885871394905173
